# %%
import pandas as pd
import numpy as np
Location = "C:/Users/RajKumar/Documents/datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
df1 = df.take(np.random.permutation(len(df))[:500])
df1
# Out:
#            fname       lname  gender  age  exercise  hours  grade  \
# 902       Steven      Graham    male   19         4     17   95.1
# 186          Gay      Wagner  female   17         4      7   75.0
# 441      Miranda     Donovan  female   16         2      4   63.7
# 1698       Oscar     Walters    male   19         3      9   79.2
# 1154       Hayes        Ware    male   16         1     17   84.9
# 1355      Gannon      Coffey    male   15         5     14   99.6
# 1089      Laurel      Bowman  female   19         5     10   91.0
# 674       Tyrone  Stephenson    male   18         5     17   91.4
# 660        Tanya     Coleman  female   19         3     10   74.6
# 1543      Angela      Macias  female   15         1      5   66.0
# 205       Ginger     Stevens  female   18         1     14   84.6
# 1793         Lev       Brown    male   17         2     10   71.8
# 355       Kadeem    Marshall    male   17         5     18  100.0
# ...
